# %% [markdown]
# # MENTORNSHIP PROJECT

# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = "ignore")

# %% [markdown]
# # Loading the data and understanding the data

# %%
Recruitment_df = pd.read_csv("Recruitment_Data (1).csv")
Recruitment_df.head()
# Out:
#    attrition  performance_rating  sales_quota_pct recruiting_source
# 0          1                   3         1.088190    Applied Online
# 1          0                   3         2.394173               NaN
# 2          1                   2         0.497530            Campus
# 3          0                   2         2.513958               NaN
# 4          0                   3         1.424789    Applied Online

# %%
Recruitment_df.shape
# Out:
# (446, 4)

# %%
Recruitment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   attrition           446 non-null    int64
#  1   performance_rating  446 non-null    int64
#  2   sales_quota_pct     446 non-null    float64
#  3   recruiting_source   241 non-null    object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
cont_vars = ["attrition", "performance_rating", "sales_quota_pct"]
cato_vars = ["recruiting_source"]

# %% [markdown]
# # CHECKING THE MISSING VALUES AND IMPUTATION OF THE MISSING VALUES

# %%
Recruitment_df.isnull().mean()
# Out:
# attrition             0.000000
# performance_rating    0.000000
# sales_quota_pct       0.000000
# recruiting_source     0.459641
# dtype: float64

# %%
#There are some missing values in recruiting_source column but since it is categorical variable we need nor impute the values.

# %% [markdown]
# # CHECKING THE OUTLIERS AND DEALING WITH IT

# %%
Recruitment_df.describe()
# Out:
#         attrition  performance_rating  sales_quota_pct
# count  446.000000          446.000000       446.000000
# mean     0.213004            2.894619         1.082607
# std      0.409891            0.683755         0.710042
# min      0.000000            1.000000        -0.710827
# 25%      0.000000            2.000000         0.584444
# 50%      0.000000            3.000000         1.070143
# 75%      0.000000            3.000000         1.532488
# max      1.000000            5.000000         3.666740

# %%
sns.boxplot(Recruitment_df["performance_rating"])
plt.show()

# %%
performance_rating_q1 = 2.00
performance_rating_q3 = 3.00
performance_rating_iqr = 3.00 - 2.00
performance_rating_upper = 3.00+1.5*1.0
performance_rating_lower = 2.00-1.5*1.00

# %%
performance_rating_upper
# Out:
# 4.5

# %%
for i in Recruitment_df["performance_rating"]:
          if i > performance_rating_upper:
            i=performance_rating_upper

Recruitment_df["performance_rating"]
# Out:
# 0      3
# 1      3
# 2      2
# 3      2
# 4      3
#       ..
# 441    3
# 442    4
# 443    4
# 444    4
# 445    2
# Name: performance_rating, Length: 446, dtype: int64

# %%
sns.boxplot(Recruitment_df["sales_quota_pct"])
plt.show()

# %%
sales_quota_pct_q1 = 0.58
sales_quota_pct_q3 = 1.53
sales_quota_pct_iqr = 1.53-0.58
sales_quota_pct_iqr
# Out:
# 0.9500000000000001

# %%
sales_quota_pct_upper = 1.53+1.5*0.95
sales_quota_pct_lower = 0.58-1.5*0.95
sales_quota_pct_upper
# Out:
# 2.955

# %%
for i in Recruitment_df["sales_quota_pct"]:
        if i > sales_quota_pct_upper:
            i=sales_quota_pct_upper

Recruitment_df["sales_quota_pct"]
# Out:
# 0      1.088190
# 1      2.394173
# 2      0.497530
# 3      2.513958
# 4      1.424789
#          ...
# 441    1.627813
# 442    0.689682
# 443    1.196198
# 444    1.598213
# 445    0.582642
# Name: sales_quota_pct, Length: 446, dtype: float64

# %% [markdown]
# # Grouping the data

# %%
grouping = Recruitment_df.groupby(["recruiting_source"]).groups

# %%
grouping
# Out:
# {'Applied Online': [0, 4, 6, 13, 16, 19, 24, 33, 34, 35, 48, 50, 54, 55, 67, 70, 71, 75, 84, 86, 88, 93, 95, 96, 98, 101, 102, 108, 109, 110, 113, 116, 118, 125, 135, 136, 141, 143, 150, 151, 152, 158, 159, 160, 169, 170, 173, 176, 178, 179, 180, 192, 193, 194, 202, 203, 209, 214, 231, 234, 236, 244, 245, 249, 251, 253, 254, 259, 263, 266, 268, 269, 274, 277, 281, 285, 290, 291, 293, 294, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 307, 315, 318, 320, 323, 332, 334, 349, 354, 355, ...], 'Campus': [2, 8, 12, 18, 28, 57, 65, 66, 80, 104, 114, 133, 137, 142, 145, 146, 148, 155, 156, 171, 175, 191, 196, 198, 199, 204, 205, 218, 221, 225, 226, 240, 250, 257, 271, 295, 306, 313, 316, 317, 337, 338, 340, 341, 344, 348, 367, 368, 372, 377, 385, 391, 411, 415, 439, 441], 'Referral': [5, 7, 25, 44, 47, 89, 94, 99, 112, 119, 124, 131, 134, 154, 165, 166, 181, 182, 189, 190, 197, 208, 211, 215, 237, 241, 243, 260, 262, 308, 312, 321, 324, 330, 345, 347, 352, 359, 380, 407, 419, 423, 428, 430, 442], 'Search Firm': [27, 38, 105, 122, 162, 227, 311, 329, 395, 406]}

# %%
 Recruitment_df.groupby(["recruiting_source"]).get_group("Applied Online")
# Out:
#      attrition  performance_rating  sales_quota_pct recruiting_source
# 0            1                   3         1.088190    Applied Online
# 4            0                   3         1.424789    Applied Online
# 6            1                   3         0.794213    Applied Online
# 13           0                   3         0.362379    Applied Online
# 16           0                   3         2.471433    Applied Online
# ..         ...                 ...              ...               ...
# 432          0                   5         1.393015    Applied Online
# 433          1                   3         1.575000    Applied Online
# 437          0                   2         0.632942    Applied Online
# 440          0                   3         1.373085    Applied Online
# 444          0                   4         1.598213    Applied Online
#
# [130 rows x 4 columns]

# %%
Recruitment_df.groupby(["recruiting_source"]).get_group("Campus")
# Out:
#      attrition  performance_rating  sales_quota_pct recruiting_source
# 2            1                   2         0.497530            Campus
# 8            0                   3         1.519917            Campus
# 12           0                   4         0.860353            Campus
# 18           0                   3         0.313106            Campus
# 28           0                   3         1.218996            Campus
# 57           1                   2        -0.020179            Campus
# 65           0                   2         1.436988            Campus
# 66           0                   3        -0.061590            Campus
# 80           0                   3         0.502660            Campus
# 104          1                   4         3.030340            Campus
# 114          0                   4         0.116946            Campus
# 133          0                   3         0.493476            Campus
# 137          0                   4         0.216157            Campus
# 142          0                   3         1.161503            Campus
# 145          1                   3         0.935256            Campus
# 146          1                   4         0.048859            Campus
# 148          0                   3         0.366818            Campus
# 155          0                   3         1.735344            Campus
# 156          0                   3         1.917377            Campus
# 171          0                   3         0.558393            Campus
# 175          1                   4         1.338921            Campus
# 191          0                   4         0.490144            Campus
# 196          0                   3         1.315082            Campus
# 198          0                   2         1.081977            Campus
# 199          0                   2        -0.239220            Campus
# 204          0                   5         1.665594            Campus
# 205          0                   3         1.552586            Campus
# 218          0                   3         1.690936            Campus
# 221          1                   3         1.663378            Campus
# 225          0                   3         0.411784            Campus
# 226          0                   4         0.357512            Campus
# 240          0                   3         0.618812            Campus
# 250          1                   2         1.081317            Campus
# 257          0                   3         0.533872            Campus
# 271          0                   2        -0.474431            Campus
# 295          0                   3        -0.556073            Campus
# 306          1                   3         0.021239            Campus
# 313          0                   3         0.567706            Campus
# 316          0                   3         1.677443            Campus
# 317          1                   3         0.589331            Campus
# 337          0                   3         0.979641            Campus
# 338          0                   2         0.903978            Campus
# 340          0                   2         2.142970            Campus
# 341          0                   2         0.778562            Campus
# 344          0                   4         0.988989            Campus
# 348          0                   3         1.277325            Campus
# 367          1                   1         1.012151            Campus
# 368          1                   2         0.933977            Campus
# 372          1                   3         3.234486            Campus
# 377          1                   3         1.473682            Campus
# 385          0                   2         1.367604            Campus
# 391          0                   3         0.225126            Campus
# 411          0                   3         0.398908            Campus
# 415          1                   2         1.414428            Campus
# 439          1                   3        -0.145816            Campus
# 441          0                   3         1.627813            Campus

# %%
Recruitment_df.groupby(["recruiting_source"]).get_group("Referral")
# Out:
#      attrition  performance_rating  sales_quota_pct recruiting_source
# 5            1                   3         0.548123          Referral
# 7            0                   2         1.006524          Referral
# 25           0                   3         0.988873          Referral
# 44           0                   2         1.001372          Referral
# 47           1                   3         0.195860          Referral
# 89           0                   3         0.825791          Referral
# 94           0                   2         1.327003          Referral
# 99           0                   3         2.483459          Referral
# 112          0                   3         0.793227          Referral
# 119          1                   1         2.120180          Referral
# 124          0                   3         1.648829          Referral
# 131          0                   4         0.982009          Referral
# 134          1                   3         0.660729          Referral
# 154          1                   3         0.305508          Referral
# 165          0                   3         0.154741          Referral
# 166          0                   2         3.666740          Referral
# 181          0                   3         0.681826          Referral
# 182          1                   3         0.453489          Referral
# 189          0                   2         0.317765          Referral
# 190          0                   3         0.281995          Referral
# 197          1                   3         0.258705          Referral
# 208          1                   3         0.809938          Referral
# 211          1                   4         0.109310          Referral
# 215          0                   3         1.491405          Referral
# 237          0                   4         0.242412          Referral
# 241          1                   4         1.262574          Referral
# 243          0                   2         0.731789          Referral
# 260          0                   3         0.421961          Referral
# 262          0                   3         1.318269          Referral
# 308          0                   2         1.870082          Referral
# 312          0                   3         1.095199          Referral
# 321          0                   4         1.054034          Referral
# 324          0                   2         0.421217          Referral
# 330          0                   3         2.142736          Referral
# 345          1                   3         0.788228          Referral
# 347          1                   3         1.130758          Referral
# 352          0                   3         0.780373          Referral
# 359          0                   3         1.423950          Referral
# 380          1                   2         1.066527          Referral
# 407          0                   4         1.107192          Referral
# 419          0                   3         1.023243          Referral
# 423          1                   1         2.025425          Referral
# 428          0                   3         0.939095          Referral
# 430          0                   2         1.395772          Referral
# 442          1                   4         0.689682          Referral

# %%
Recruitment_df.groupby(["recruiting_source"]).get_group("Search Firm")
# Out:
#      attrition  performance_rating  sales_quota_pct recruiting_source
# 27           1                   2         1.867939       Search Firm
# 38           0                   3         1.294592       Search Firm
# 105          1                   3         1.258933       Search Firm
# 122          0                   3        -0.064948       Search Firm
# 162          1                   2        -0.628092       Search Firm
# 227          1                   3         1.595868       Search Firm
# 311          0                   3         1.325476       Search Firm
# 329          0                   2         0.678046       Search Firm
# 395          1                   3         1.352784       Search Firm
# 406          0                   3         0.189004       Search Firm

# %% [markdown]
# # Grouping the data by the mean value

# %%
mean_group = Recruitment_df.groupby(["recruiting_source"]).mean()
mean_group
# Out:
#                    attrition  performance_rating  sales_quota_pct
# recruiting_source
# Applied Online      0.246154            2.930769         1.058590
# Campus              0.285714            2.928571         0.908035
# Referral            0.333333            2.844444         1.023198
# Search Firm         0.500000            2.700000         0.886960

# %% [markdown]
# # By looking at the average values we can say that one of the best recruiting source is "Applied Online"as the applied online group have low attrition average and high sales average whereas the worst recruiting source would be the "Search Firm" which have high attrition and low sales value

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(Recruitment_df)
plt.show()

# %% [markdown]
# All the three variables have no particular relation with each other.

# %%
sns.heatmap(Recruitment_df.corr())
plt.show()

# %% [markdown]
# The variables are weakly correlated to each other.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.barplot(Recruitment_df["recruiting_source"],Recruitment_df["attrition"])
plt.show()

# %% [markdown]
# # The barchart shows that the employees selected from 'Applied Online' has the low attrition proving to be more productive employees and thus the 'Applied Online' is the best recruiting source.Whereas employeesselected from 'Search Firm' has high attrition soo 'Search Firm' is the worst recruiting source.

# %%
sns.barplot(Recruitment_df["recruiting_source"],Recruitment_df["sales_quota_pct"])
plt.show()

# %% [markdown]
# # The employees selected from 'Applied Online' and 'Referral' has generated the highest sales for the company so,proving to be the best recruiting source.Whereas the employees selected from  'Search Firm' has generated low sale soo it is the worst recruiting source.

# %%
sns.barplot(Recruitment_df["recruiting_source"],Recruitment_df["performance_rating"])
plt.show()

# %% [markdown]
# # The employees sourced from'Applied Online' and 'Campus' shows high performance_rating while the employeed sourced from 'Search Firm' shows lowest performance_rating compared to other sources.

# %% [markdown]
# # Conclusion

# %% [markdown]
# # The best recruiting source for the tech startup company is the "Applied Online".
# The reason behind "Applied Online" being the best recruitment source are :
#
#     1. The employees selected from "Applied Online" has generated greater amount of sales for the company
#     compared to the employees selected from other sources.
#
#     2. The employees selected from "Applied Online" has the lowest attrition value compared to
#     the employees selected from other sources.
